# %%
import torch

a = torch.ones(4, 3, 3, 2)
print(f"a.shape: {a.shape}")
b = torch.rand(3, 3)
print(f"b.shape: {b.shape}")
c = b.unsqueeze(2)
print(f"c.shape: {c.shape}")
print(f"a * c: {a * c}")
# Out:
# a.shape: torch.Size([4, 3, 3, 2])
# b.shape: torch.Size([3, 3])
# c.shape: torch.Size([3, 3, 1])
# a * c: tensor([[[[0.0196, 0.0196],
#           [0.1263, 0.1263],
#           [0.6839, 0.6839]],
#
#          [[0.8463, 0.8463],
#           [0.3327, 0.3327],
#           [0.0057, 0.0057]],
#
#          [[0.3379, 0.3379],
#           [0.0747, 0.0747],
#           [0.2343, 0.2343]]],
#
#
#         [[[0.0196, 0.0196],
#           [0.1263, 0.1263],
#           [0.6839, 0.6839]],
#
#          [[0.8463, 0.8463],
#           [0.3327, 0.3327],
#           [0.0057, 0.0057]],
#
#          [[0.3379, 0.3379],
#           [0.0747, 0.0747],
#           [0.2343, 0.2343]]],
#
#
#         [[[0.0196, 0.0196],
#           [0.1263, 0.1263],
#           [0.6839, 0.6839]],
#
#          [[0.8463, 0.8463],
#           [0.3327, 0.3327],
#           [0.0057, 0.0057]],
#
#          [[0.3379, 0.3379],
#           [0.0747, 0.0747],
#           [0.2343, 0.2343]]],
#
#
#         [[[0.0196, 0.0196],
# ...
